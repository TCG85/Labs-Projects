# %% [markdown]
# # Job Board Scraping Lab
#
# In this lab you will first see a minimal but fully functional code snippet to scrape the LinkedIn Job Search webpage. You will then work on top of the example code and complete several chanllenges.
#
# ### Some Resources
#
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %%
# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search(keywords):
    
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    BASE_URL = 'https://www.linkedin.com/jobs/search/?'
    
    # Assemble the full url with parameters
    scrape_url = ''.join([BASE_URL, 'keywords=', keywords])

    # Create a request to get the data from the server 
    page = requests.get(scrape_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Create an empty dataframe with the columns consisting of the information you want to capture
    columns = ['Title', 'Company', 'Location']
    data = pd.DataFrame(columns=columns)

    # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
    # Then in each job card, extract the job title, company, and location data.
    titles = []
    companies = []
    locations = []
    for card in soup.select("div.result-card__contents"):
        title = card.findChild("h3", recursive=False)
        company = card.findChild("h4", recursive=False)
        location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
        titles.append(title.string)
        companies.append(company.string)
        locations.append(location.string)
    
    # Inject job titles, companies, and locations into the empty dataframe
    zipped = zip(titles, companies, locations)
    for z in list(zipped):
        data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
    
    # Return dataframe
    return data

# %%
# Example to call the function

results = scrape_linkedin_job_search('data%20analysis')
results
# Out:
#                                      Title  \
# 0                             Data Analyst
# 1                             Data Analyst
# 2                   VP Data Transformation
# 3                           Data Scientist
# 4                             Data Analyst
# 5                         Data Ops Analyst
# 6                             Data Analyst
# 7                    Data Strategy Analyst
# 8                             Data Analyst
# 9                   Strategic Data Analyst
# 10                            Data Analyst
# 11                            Data Analyst
# 12  Data and Business Intelligence Analyst
# 13        Reporting & Metrics Data Analyst
# 14                            Data Analyst
# 15                                 Analyst
# 16      Data Analyst, Workforce Management
# 17                            Data Analyst
# 18                            Data Analyst
# 19                            Data Analyst
# 20          Crime and Intelligence Analyst
# 21                   Data Analyst, Digital
# 22                Data & Reporting Analyst
# 23                            Data Analyst
# 24                            Data Analyst
#
#                                     Company  \
# 0                                 MakeSpace
# 1   University of Colorado Colorado Springs
# 2                        Centria Healthcare
# 3                 BMW of North America, LLC
# 4                      Hollstadt Consulting
# 5                                      Wish
# 6                           Quest Financial
# 7                            Payden & Rygel
# 8                   State of North Carolina
# 9                    PDC - A Brady Business
# 10                               TEKsystems
# 11                           Eliassen Group
# 12                              Times Union
# 13                                   Airbnb
# 14                         Marchon Partners
# 15                                   YouGov
# 16                     Sun Country Airlines
# 17                           Progressive GE
# 18             Versique Search & Consulting
# 19                                     IPSY
# 20               San Jose Police Department
# 21                        HAUS LABORATORIES
# 22                                  Astravo
# 23                                   EPITEC
# 24                                Intuitive
#
#                                      Location
# 0           New York, New York, United States
# 1                    Colorado Springs, CO, US
# 2   Farmington Hills, Michigan, United States
# 3                      Woodcliff Lake, NJ, US
# 4           Greater Minneapolis-St. Paul Area
# 5                       San Francisco, CA, US
# 6            Dunwoody, Georgia, United States
# 7      Los Angeles, California, United States
# 8                             Raleigh, NC, US
# 9                        Valencia, California
# 10          Summit, New Jersey, United States
# 11              Tampa, Florida, United States
# 12                           Albany, New York
# 13                      San Francisco, CA, US
# 14                            Charlotte Metro
# 15       Cheshire, Connecticut, United States
# 16                        Minneapolis, MN, US
# 17                      San Diego, California
# 18                            Hopkins, MN, US
# 19                          San Mateo, CA, US
# 20        San Jose, California, United States
# 21     Los Angeles, California, United States
# 22                        Greater Denver Area
# 23                Plano, Texas, United States
# 24                            Raleigh, NC, US

# %% [markdown]
# ## Challenge 1
#
# The first challenge for you is to update the `scrape_linkedin_job_search` function by adding a new parameter called `num_pages`. This will allow you to search more than 25 jobs with this function. Suggested steps:
#
# 1. Go to https://www.linkedin.com/jobs/search/?keywords=data%20analysis in your browser.
# 1. Scroll down the left panel and click the page 2 link. Look at how the URL changes and identify the page offset parameter.
# 1. Add `num_pages` as a new param to the `scrape_linkedin_job_search` function. Update the function code so that it uses a "for" loop to retrieve several pages of search results.
# 1. Test your new function by scraping 5 pages of the search results.
#
# Hint: Prepare for the case where there are less than 5 pages of search results. Your function should be robust enough to **not** trigger errors. Simply skip making additional searches and return all results if the search already reaches the end.

# %%
# your code here

pd.set_option('display.max_rows', 500) 
    
# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search_pages(keywords, num_pages):
    
        # Define the base url to be scraped.
        # All uppercase variable name signifies this is a constant and its value should never unchange
        BASE_URL = 'https://www.linkedin.com/jobs/search/?'
                   
        #page_counter = 0
        titles = []
        companies = []
        locations = []
        # Create an empty dataframe with the columns consisting of the information you want to capture
        columns = ['Title', 'Company', 'Location']
        data = pd.DataFrame(columns=columns)
            
        for page in range(num_pages):
     
            
            # Assemble the full url with parameters
            scrape_url = ''.join([BASE_URL, 'keywords=', keywords, '&start=', str(page*25)])
            
            # Create a request to get the data from the server 
            page = requests.get(scrape_url)
            soup = BeautifulSoup(page.text, 'html.parser')
            
            
            
            # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
            # Then in each job card, extract the job title, company, and location data.
            
            for card in soup.select("div.result-card__contents"):
                title = card.findChild("h3", recursive=False)
                company = card.findChild("h4", recursive=False)
                location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
                titles.append(title.string)
                companies.append(company.string)
                locations.append(location.string)
            
        # Inject job titles, companies, and locations into the empty dataframe
        zipped = zip(titles, companies, locations)
        for z in list(zipped):
            data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
                         
        # Return dataframe
        return data

results_2 = scrape_linkedin_job_search_pages('data%20analysis', 3)
results_2.head(75)
# Out:
#                                          Title  \
# 0                                 Data Analyst
# 1                       VP Data Transformation
# 2                               Data Scientist
# 3                                 Data Analyst
# 4                                 Data Analyst
# 5                             Data Ops Analyst
# 6                                 Data Analyst
# 7             Reporting & Metrics Data Analyst
# 8                        Data Strategy Analyst
# 9                       Associate Data Analyst
# 10                                Data Analyst
# 11                      Strategic Data Analyst
# 12                                Data Analyst
# 13                                Data Analyst
# 14      Data and Business Intelligence Analyst
# 15                 Analyst, Data and Analytics
# 16                                Data Analyst
# 17  Data Scientist, Charging Data and Modeling
# 18                                     Analyst
# 19                                Data Analyst
# 20                                Data Analyst
# 21                                Data Analyst
# 22                                Data Analyst
# 23                       Data Analyst, Digital
# 24                                Data Analyst
# 25                                Data Analyst
# 26                                Data Analyst
# 27                      VP Data Transformation
# 28                              Data Scientist
# 29                                Data Analyst
# 30                            Data Ops Analyst
# 31                                Data Analyst
# 32                       Data Strategy Analyst
# 33                                Data Analyst
# 34                      Strategic Data Analyst
# 35                                Data Analyst
# 36                                Data Analyst
# 37      Data and Business Intelligence Analyst
# 38            Reporting & Metrics Data Analyst
# 39                                Data Analyst
# 40                                     Analyst
# 41          Data Analyst, Workforce Management
# 42                                Data Analyst
# 43                                Data Analyst
# 44                                Data Analyst
# 45              Crime and Intelligence Analyst
# 46                       Data Analyst, Digital
# 47                    Data & Reporting Analyst
# 48                                Data Analyst
# 49                                Data Analyst
# 50                                Data Analyst
# 51                      VP Data Transformation
# 52                              Data Scientist
# 53                            Data Ops Analyst
# 54                                Data Analyst
# 55                       Data Strategy Analyst
# 56                      Associate Data Analyst
# 57                                Data Analyst
# 58                      Strategic Data Analyst
# 59                                Data Analyst
# 60                                Data Analyst
# 61      Data and Business Intelligence Analyst
# 62            Reporting & Metrics Data Analyst
# 63                 Analyst, Data and Analytics
# 64                Analytics - Insights Analyst
# 65                                Data Analyst
# 66  Data Scientist, Charging Data and Modeling
# 67                                     Analyst
# 68                                Data Analyst
# 69                                Data Analyst
# 70                                Data Analyst
# 71                                Data Analyst
# 72                       Data Analyst, Digital
# 73                                Data Analyst
# 74                     ANALYST, DATA ANALYTICS
#
#                                     Company  \
# 0                                 MakeSpace
# 1                        Centria Healthcare
# 2                 BMW of North America, LLC
# 3                      Hollstadt Consulting
# 4                             Planted, Inc.
# 5                                      Wish
# 6                           Quest Financial
# 7                                    Airbnb
# 8                            Payden & Rygel
# 9                                  ZoomInfo
# 10                  State of North Carolina
# 11                   PDC - A Brady Business
# 12                               TEKsystems
# 13                           Eliassen Group
# 14                              Times Union
# 15                    Digitas North America
# 16                         Marchon Partners
# 17                                    Tesla
# 18                                   YouGov
# 19                           Progressive GE
# 20             Versique Search & Consulting
# 21                                     IPSY
# 22                              Dixon Valve
# 23                        HAUS LABORATORIES
# 24                                   EPITEC
# 25                                MakeSpace
# 26  University of Colorado Colorado Springs
# 27                       Centria Healthcare
# 28                BMW of North America, LLC
# 29                     Hollstadt Consulting
# 30                                     Wish
# 31                          Quest Financial
# 32                           Payden & Rygel
# 33                  State of North Carolina
# 34                   PDC - A Brady Business
# 35                               TEKsystems
# 36                           Eliassen Group
# 37                              Times Union
# 38                                   Airbnb
# 39                         Marchon Partners
# 40                                   YouGov
# 41                     Sun Country Airlines
# 42                           Progressive GE
# 43             Versique Search & Consulting
# 44                                     IPSY
# 45               San Jose Police Department
# 46                        HAUS LABORATORIES
# 47                                  Astravo
# 48                                   EPITEC
# 49                                Intuitive
# 50                                MakeSpace
# 51                       Centria Healthcare
# 52                BMW of North America, LLC
# 53                                     Wish
# 54                          Quest Financial
# 55                           Payden & Rygel
# 56                                 ZoomInfo
# 57                  State of North Carolina
# 58                   PDC - A Brady Business
# 59                               TEKsystems
# 60                           Eliassen Group
# 61                              Times Union
# 62                                   Airbnb
# 63                    Digitas North America
# 64                                    Starz
# 65                         Marchon Partners
# 66                                    Tesla
# 67                                   YouGov
# 68                           Progressive GE
# 69             Versique Search & Consulting
# 70                                     IPSY
# 71                              Dixon Valve
# 72                        HAUS LABORATORIES
# 73                                   EPITEC
# 74                           BJC HealthCare
#
#                                      Location
# 0           New York, New York, United States
# 1   Farmington Hills, Michigan, United States
# 2                      Woodcliff Lake, NJ, US
# 3           Greater Minneapolis-St. Paul Area
# 4                       New York City, NY, US
# 5                       San Francisco, CA, US
# 6            Dunwoody, Georgia, United States
# 7                       San Francisco, CA, US
# 8      Los Angeles, California, United States
# 9                           Vancouver, WA, US
# 10                            Raleigh, NC, US
# 11                       Valencia, California
# 12          Summit, New Jersey, United States
# 13              Tampa, Florida, United States
# 14                           Albany, New York
# 15                 Greater New York City Area
# 16                            Charlotte Metro
# 17                          Palo Alto, CA, US
# 18       Cheshire, Connecticut, United States
# 19                      San Diego, California
# 20                            Hopkins, MN, US
# 21                          San Mateo, CA, US
# 22       Chestertown, Maryland, United States
# 23     Los Angeles, California, United States
# 24                Plano, Texas, United States
# 25          New York, New York, United States
# 26                   Colorado Springs, CO, US
# 27  Farmington Hills, Michigan, United States
# 28                     Woodcliff Lake, NJ, US
# 29          Greater Minneapolis-St. Paul Area
# 30                      San Francisco, CA, US
# 31           Dunwoody, Georgia, United States
# 32     Los Angeles, California, United States
# 33                            Raleigh, NC, US
# 34                       Valencia, California
# 35          Summit, New Jersey, United States
# 36              Tampa, Florida, United States
# 37                           Albany, New York
# 38                      San Francisco, CA, US
# 39                            Charlotte Metro
# 40       Cheshire, Connecticut, United States
# 41                        Minneapolis, MN, US
# 42                      San Diego, California
# 43                            Hopkins, MN, US
# 44                          San Mateo, CA, US
# 45        San Jose, California, United States
# 46     Los Angeles, California, United States
# 47                        Greater Denver Area
# 48                Plano, Texas, United States
# 49                            Raleigh, NC, US
# 50          New York, New York, United States
# 51  Farmington Hills, Michigan, United States
# 52                     Woodcliff Lake, NJ, US
# 53                      San Francisco, CA, US
# 54           Dunwoody, Georgia, United States
# 55     Los Angeles, California, United States
# 56                          Vancouver, WA, US
# 57                            Raleigh, NC, US
# 58                       Valencia, California
# 59          Summit, New Jersey, United States
# 60              Tampa, Florida, United States
# 61                           Albany, New York
# 62                      San Francisco, CA, US
# 63                 Greater New York City Area
# 64            New York City Metropolitan Area
# 65                            Charlotte Metro
# 66                          Palo Alto, CA, US
# 67       Cheshire, Connecticut, United States
# 68                      San Diego, California
# 69                            Hopkins, MN, US
# 70                          San Mateo, CA, US
# 71       Chestertown, Maryland, United States
# 72     Los Angeles, California, United States
# 73                Plano, Texas, United States
# 74                          St. Louis, MO, US

# %% [markdown]
# ## Challenge 2
#
# Further improve your function so that it can search jobs in a specific country. Add the 3rd param to your function called `country`. The steps are identical to those in Challange 1.

# %%
# your code here

pd.set_option('display.max_rows', 500) 
    
# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search_pages(keywords, country, num_pages):
    
        # Define the base url to be scraped.
        # All uppercase variable name signifies this is a constant and its value should never unchange
        BASE_URL = 'https://www.linkedin.com/jobs/search/?'
                   
        #page_counter = 0
        titles = []
        companies = []
        locations = []
        # Create an empty dataframe with the columns consisting of the information you want to capture
        columns = ['Title', 'Company', 'Location']
        data = pd.DataFrame(columns=columns)
            
        for i in range(num_pages):
     
            
            # Assemble the full url with parameters
            scrape_url = ''.join([BASE_URL, 'keywords=', keywords, '&location=', country, '&start=', str(i*25)])
            
            # Create a request to get the data from the server 
            page = requests.get(scrape_url)
            soup = BeautifulSoup(page.text, 'html.parser')
            
            
            
            # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
            # Then in each job card, extract the job title, company, and location data.
            
            for card in soup.select("div.result-card__contents"):
                title = card.findChild("h3", recursive=False)
                company = card.findChild("h4", recursive=False)
                location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
                titles.append(title.string)
                companies.append(company.string)
                locations.append(location.string)
            
        # Inject job titles, companies, and locations into the empty dataframe
        zipped = zip(titles, companies, locations)
        for z in list(zipped):
            data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
                         
        # Return dataframe
        return data

results_3 = scrape_linkedin_job_search_pages('cluster%20lead', 'munich', 10)
results_3
# Out:
#                                              Title  \
# 0                          Cluster Lead, Market HR
# 1                           CRM Specialist (m/f/d)
# 2           Head of Financial Control (m/w/d) DACH
# 3                          Medical Science Liasion
# 4                        Transport Carrier Manager
# 5                Transport Carrier Manager (m/w/d)
# 6                  Senior Backend Engineer (m/f/d)
# 7             Senior React Native Engineer (m/f/d)
# 8   Senior Software Engineer: JS Fullstack (m/f/d)
# 9                          Cluster Lead, Market HR
# 10                          CRM Specialist (m/f/d)
# 11          Head of Financial Control (m/w/d) DACH
# 12                         Medical Science Liasion
# 13                       Transport Carrier Manager
# 14               Transport Carrier Manager (m/w/d)
# 15                 Senior Backend Engineer (m/f/d)
# 16            Senior React Native Engineer (m/f/d)
# 17  Senior Software Engineer: JS Fullstack (m/f/d)
# 18                         Cluster Lead, Market HR
# 19                          CRM Specialist (m/f/d)
# 20          Head of Financial Control (m/w/d) DACH
# 21                         Medical Science Liasion
# 22                       Transport Carrier Manager
# 23               Transport Carrier Manager (m/w/d)
# 24                 Senior Backend Engineer (m/f/d)
# 25            Senior React Native Engineer (m/f/d)
# 26  Senior Software Engineer: JS Fullstack (m/f/d)
# 27                         Cluster Lead, Market HR
# 28                          CRM Specialist (m/f/d)
# 29          Head of Financial Control (m/w/d) DACH
# 30                         Medical Science Liasion
# 31                       Transport Carrier Manager
# 32               Transport Carrier Manager (m/w/d)
# 33                 Senior Backend Engineer (m/f/d)
# 34            Senior React Native Engineer (m/f/d)
# 35  Senior Software Engineer: JS Fullstack (m/f/d)
# 36                         Cluster Lead, Market HR
# 37                          CRM Specialist (m/f/d)
# 38          Head of Financial Control (m/w/d) DACH
# 39                         Medical Science Liasion
# 40                       Transport Carrier Manager
# 41               Transport Carrier Manager (m/w/d)
# 42                 Senior Backend Engineer (m/f/d)
# 43            Senior React Native Engineer (m/f/d)
# 44  Senior Software Engineer: JS Fullstack (m/f/d)
# 45                         Cluster Lead, Market HR
# 46                          CRM Specialist (m/f/d)
# 47          Head of Financial Control (m/w/d) DACH
# 48                         Medical Science Liasion
# 49                       Transport Carrier Manager
# 50               Transport Carrier Manager (m/w/d)
# 51                 Senior Backend Engineer (m/f/d)
# 52            Senior React Native Engineer (m/f/d)
# 53  Senior Software Engineer: JS Fullstack (m/f/d)
# 54                         Cluster Lead, Market HR
# 55                          CRM Specialist (m/f/d)
# 56          Head of Financial Control (m/w/d) DACH
# 57                         Medical Science Liasion
# 58                       Transport Carrier Manager
# 59               Transport Carrier Manager (m/w/d)
# 60                 Senior Backend Engineer (m/f/d)
# 61            Senior React Native Engineer (m/f/d)
# 62  Senior Software Engineer: JS Fullstack (m/f/d)
# 63                         Cluster Lead, Market HR
# 64                          CRM Specialist (m/f/d)
# 65          Head of Financial Control (m/w/d) DACH
# 66                         Medical Science Liasion
# 67                       Transport Carrier Manager
# 68               Transport Carrier Manager (m/w/d)
# 69                 Senior Backend Engineer (m/f/d)
# 70            Senior React Native Engineer (m/f/d)
# 71  Senior Software Engineer: JS Fullstack (m/f/d)
# 72                         Cluster Lead, Market HR
# 73          Head of Financial Control (m/w/d) DACH
# 74                          CRM Specialist (m/f/d)
# 75                         Medical Science Liasion
# 76            Senior React Native Engineer (m/f/d)
# 77                       Transport Carrier Manager
# 78               Transport Carrier Manager (m/w/d)
# 79  Senior Software Engineer: JS Fullstack (m/f/d)
# 80                 Senior Backend Engineer (m/f/d)
# 81                         Cluster Lead, Market HR
# 82                          CRM Specialist (m/f/d)
# 83          Head of Financial Control (m/w/d) DACH
# 84                         Medical Science Liasion
# 85                       Transport Carrier Manager
# 86               Transport Carrier Manager (m/w/d)
# 87                 Senior Backend Engineer (m/f/d)
# 88            Senior React Native Engineer (m/f/d)
# 89  Senior Software Engineer: JS Fullstack (m/f/d)
#
#                              Company    Location
# 0                             Google  Munich, DE
# 1                      Tiffany & Co.  Munich, DE
# 2                             Danone  Munich, DE
# 3            Alnylam Pharmaceuticals  Munich, DE
# 4                             Amazon  Munich, DE
# 5   Amazon Deutschland Services GmbH  Munich, DE
# 6                             Motius  Munich, DE
# 7                             Motius  Munich, DE
# 8                             Motius  Munich, DE
# 9                             Google  Munich, DE
# 10                     Tiffany & Co.  Munich, DE
# 11                            Danone  Munich, DE
# 12           Alnylam Pharmaceuticals  Munich, DE
# 13                            Amazon  Munich, DE
# 14  Amazon Deutschland Services GmbH  Munich, DE
# 15                            Motius  Munich, DE
# 16                            Motius  Munich, DE
# 17                            Motius  Munich, DE
# 18                            Google  Munich, DE
# 19                     Tiffany & Co.  Munich, DE
# 20                            Danone  Munich, DE
# 21           Alnylam Pharmaceuticals  Munich, DE
# 22                            Amazon  Munich, DE
# 23  Amazon Deutschland Services GmbH  Munich, DE
# 24                            Motius  Munich, DE
# 25                            Motius  Munich, DE
# 26                            Motius  Munich, DE
# 27                            Google  Munich, DE
# 28                     Tiffany & Co.  Munich, DE
# 29                            Danone  Munich, DE
# 30           Alnylam Pharmaceuticals  Munich, DE
# 31                            Amazon  Munich, DE
# 32  Amazon Deutschland Services GmbH  Munich, DE
# 33                            Motius  Munich, DE
# 34                            Motius  Munich, DE
# 35                            Motius  Munich, DE
# 36                            Google  Munich, DE
# 37                     Tiffany & Co.  Munich, DE
# 38                            Danone  Munich, DE
# 39           Alnylam Pharmaceuticals  Munich, DE
# 40                            Amazon  Munich, DE
# 41  Amazon Deutschland Services GmbH  Munich, DE
# 42                            Motius  Munich, DE
# 43                            Motius  Munich, DE
# 44                            Motius  Munich, DE
# 45                            Google  Munich, DE
# 46                     Tiffany & Co.  Munich, DE
# 47                            Danone  Munich, DE
# 48           Alnylam Pharmaceuticals  Munich, DE
# 49                            Amazon  Munich, DE
# 50  Amazon Deutschland Services GmbH  Munich, DE
# 51                            Motius  Munich, DE
# 52                            Motius  Munich, DE
# 53                            Motius  Munich, DE
# 54                            Google  Munich, DE
# 55                     Tiffany & Co.  Munich, DE
# 56                            Danone  Munich, DE
# 57           Alnylam Pharmaceuticals  Munich, DE
# 58                            Amazon  Munich, DE
# 59  Amazon Deutschland Services GmbH  Munich, DE
# 60                            Motius  Munich, DE
# 61                            Motius  Munich, DE
# 62                            Motius  Munich, DE
# 63                            Google  Munich, DE
# 64                     Tiffany & Co.  Munich, DE
# 65                            Danone  Munich, DE
# 66           Alnylam Pharmaceuticals  Munich, DE
# 67                            Amazon  Munich, DE
# 68  Amazon Deutschland Services GmbH  Munich, DE
# 69                            Motius  Munich, DE
# 70                            Motius  Munich, DE
# 71                            Motius  Munich, DE
# 72                            Google  Munich, DE
# 73                            Danone  Munich, DE
# 74                     Tiffany & Co.  Munich, DE
# 75           Alnylam Pharmaceuticals  Munich, DE
# 76                            Motius  Munich, DE
# 77                            Amazon  Munich, DE
# 78  Amazon Deutschland Services GmbH  Munich, DE
# 79                            Motius  Munich, DE
# 80                            Motius  Munich, DE
# 81                            Google  Munich, DE
# 82                     Tiffany & Co.  Munich, DE
# 83                            Danone  Munich, DE
# 84           Alnylam Pharmaceuticals  Munich, DE
# 85                            Amazon  Munich, DE
# 86  Amazon Deutschland Services GmbH  Munich, DE
# 87                            Motius  Munich, DE
# 88                            Motius  Munich, DE
# 89                            Motius  Munich, DE

# %% [markdown]
# ## Challenge 3
#
# Add the 4th param called `num_days` to your function to allow it to search jobs posted in the past X days. Note that in the LinkedIn job search the searched timespan is specified with the following param:
#
# ```
# f_TPR=r259200
# ```
#
# The number part in the param value is the number of seconds. 259,200 seconds equal to 3 days. You need to convert `num_days` to number of seconds and supply that info to LinkedIn job search.

# %%
# your code here

pd.set_option('display.max_rows', 500) 
    
# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search_pages(keywords, country, num_pages, num_days):
    
        # Define the base url to be scraped.
        # All uppercase variable name signifies this is a constant and its value should never unchange
        BASE_URL = 'https://www.linkedin.com/jobs/search/?'
                   
        #page_counter = 0
        titles = []
        companies = []
        locations = []
        # Create an empty dataframe with the columns consisting of the information you want to capture
        columns = ['Title', 'Company', 'Location']
        data = pd.DataFrame(columns=columns)
            
        for i in range(num_pages):
     
            
            # Assemble the full url with parameters
            scrape_url = ''.join([BASE_URL, 'f_TPR=r', str((259200/3)*num_days),'keywords=', keywords, '&location=', country, '&start=', str(i*25)])
            
            # Create a request to get the data from the server 
            page = requests.get(scrape_url)
            soup = BeautifulSoup(page.text, 'html.parser')
            
            
            
            # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
            # Then in each job card, extract the job title, company, and location data.
            
            for card in soup.select("div.result-card__contents"):
                title = card.findChild("h3", recursive=False)
                company = card.findChild("h4", recursive=False)
                location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
                titles.append(title.string)
                companies.append(company.string)
                locations.append(location.string)
            
        # Inject job titles, companies, and locations into the empty dataframe
        zipped = zip(titles, companies, locations)
        for z in list(zipped):
            data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
                         
        # Return dataframe
        return data

results_4 = scrape_linkedin_job_search_pages('cluster%20lead', 'Munich', 5, 0)
results_4
# Out:
#                                                  Title  \
# 0                         Software Developer (m/w) C++
# 1                    Functional Safety Manager (f/m/d)
# 2                Sales Account Manager, Süddeutschland
# 3                            Marketing Manager (f/m/d)
# 4                                    Portfolio Analyst
# 5               Product Owner Data & Reporting (m/w/d)
# 6    Risk Analyst Life Risk Center of Competence (m...
# 7                     Full Stack Web Developer (m/w/d)
# 8    TEAM LEAD RETAIL MARKETING & EVENT MANAGER EUR...
# 9    Kundenbetreuer (w/m/d) Versicherungen für Gewe...
# 10                       STEUERFACHANGSTELLTER (m/w/d)
# 11                                    Account Director
# 12                Channel Account Manager DACH (m/f/d)
# 13                                           Recruiter
# 14                  Manager Regulatory Affairs (m/w/d)
# 15                           Quality Assurance Officer
# 16                         Director of Finance (m/w/d)
# 17           Postdoc - computational biologist (f/m/d)
# 18                            PDK Development Engineer
# 19                               Sales Engineer - DACH
# 20                          Personal Assistant (m/w/d)
# 21                 SAINT LAURENT Sales Assistant W/M/D
# 22                                 Senior Statistician
# 23   Payment Coordinator - Home Base Possible - Ger...
# 24                   (Junior) Project Engineer (m/w/d)
# 25                                           Schlosser
# 26                          Personal Assistant (m/w/d)
# 27                 Key Account Manager (m/w/d) Avionik
# 28                           Digital Marketing Manager
# 29                       Junior Data Scientist (f/m/d)
# 30                             Volljuristin/Volljurist
# 31                                 Strategy Consultant
# 32                                   Grafikdesigner/in
# 33   Marketing Specialist - Schwerpunkt Event & Sal...
# 34      Project Manager (m, f, d) - anywhere in Europe
# 35                          Training Koordinator (m/w)
# 36                                       HDI Global SE
# 37                                Data Scientist (m/w)
# 38                                  Operations Manager
# 39                          Marketingassistenz (m/w/d)
# 40                                   Portfolio Analyst
# 41                Stellvertretende Marktleiter (w/m/d)
# 42   Administration and Documentation Specialist / ...
# 43                              Logistikplaner (m/w/d)
# 44                        Exportsachbearbeiter (m/w/d)
# 45      HR Mitarbeiter (m/w/d) internationaler Konzern
# 46                            Learning Program Manager
# 47                           Quality Assurance Officer
# 48             Data Analyst / Business Analyst (m/w/d)
# 49                         Wissenschaftliche Mitarbeit
# 50                                           Schlosser
# 51                          Personal Assistant (m/w/d)
# 52                 Key Account Manager (m/w/d) Avionik
# 53                           Digital Marketing Manager
# 54                       Junior Data Scientist (f/m/d)
# 55                             Volljuristin/Volljurist
# 56                                 Strategy Consultant
# 57                                   Grafikdesigner/in
# 58   Marketing Specialist - Schwerpunkt Event & Sal...
# 59      Project Manager (m, f, d) - anywhere in Europe
# 60                          Training Koordinator (m/w)
# 61                                       HDI Global SE
# 62                                Data Scientist (m/w)
# 63                                  Operations Manager
# 64                          Marketingassistenz (m/w/d)
# 65                                   Portfolio Analyst
# 66                Stellvertretende Marktleiter (w/m/d)
# 67   Administration and Documentation Specialist / ...
# 68                              Logistikplaner (m/w/d)
# 69                        Exportsachbearbeiter (m/w/d)
# 70      HR Mitarbeiter (m/w/d) internationaler Konzern
# 71                            Learning Program Manager
# 72                           Quality Assurance Officer
# 73             Data Analyst / Business Analyst (m/w/d)
# 74                         Wissenschaftliche Mitarbeit
# 75                        Software Developer (m/w) C++
# 76                   Functional Safety Manager (f/m/d)
# 77               Sales Account Manager, Süddeutschland
# 78                           Marketing Manager (f/m/d)
# 79                                   Portfolio Analyst
# 80              Product Owner Data & Reporting (m/w/d)
# 81   Risk Analyst Life Risk Center of Competence (m...
# 82                    Full Stack Web Developer (m/w/d)
# 83   TEAM LEAD RETAIL MARKETING & EVENT MANAGER EUR...
# 84   Kundenbetreuer (w/m/d) Versicherungen für Gewe...
# 85                       STEUERFACHANGSTELLTER (m/w/d)
# 86                                    Account Director
# 87                Channel Account Manager DACH (m/f/d)
# 88                                           Recruiter
# 89                  Manager Regulatory Affairs (m/w/d)
# 90                           Quality Assurance Officer
# 91                         Director of Finance (m/w/d)
# 92           Postdoc - computational biologist (f/m/d)
# 93                            PDK Development Engineer
# 94                               Sales Engineer - DACH
# 95                          Personal Assistant (m/w/d)
# 96                 SAINT LAURENT Sales Assistant W/M/D
# 97                                 Senior Statistician
# 98   Payment Coordinator - Home Base Possible - Ger...
# 99                   (Junior) Project Engineer (m/w/d)
# 100                                          Schlosser
# 101                         Personal Assistant (m/w/d)
# 102                          Digital Marketing Manager
# 103                      Junior Data Scientist (f/m/d)
# 104                            Volljuristin/Volljurist
# 105                                Strategy Consultant
# 106                                  Grafikdesigner/in
# 107                Key Account Manager (m/w/d) Avionik
# 108  Marketing Specialist - Schwerpunkt Event & Sal...
# 109     Project Manager (m, f, d) - anywhere in Europe
# 110                         Training Koordinator (m/w)
# 111                                      HDI Global SE
# 112                               Data Scientist (m/w)
# 113  Administration and Documentation Specialist / ...
# 114                                 Operations Manager
# 115                         Marketingassistenz (m/w/d)
# 116               Stellvertretende Marktleiter (w/m/d)
# 117                             Logistikplaner (m/w/d)
# 118                       Exportsachbearbeiter (m/w/d)
# 119     HR Mitarbeiter (m/w/d) internationaler Konzern
# 120                           Learning Program Manager
# 121                             Credit Analyst (m/f/d)
# 122                                  Portfolio Analyst
# 123                        Wissenschaftliche Mitarbeit
# 124                                          Schlosser
#
#                                                Company  \
# 0                                      Bundesdruckerei
# 1                                                 KPIT
# 2                                    Euronet Worldwide
# 3                          Technical University Munich
# 4                                                PIMCO
# 5    metafinanz Informationssysteme GmbH (Allianz G...
# 6                                              Allianz
# 7                                            Abalon AB
# 8                                          VIU Eyewear
# 9                           Personalwerk Sourcing GmbH
# 10                                RS for business GmbH
# 11                                       Syneos Health
# 12                                               Infor
# 13                                       SYSTEMIQ Ltd.
# 14                                     Astellas Europe
# 15                                   Accord Healthcare
# 16                                       hilton hotels
# 17                           Helmholtz Zentrum München
# 18                           RequireTech Resources Ltd
# 19                                          Cybereason
# 20                                       Roland Berger
# 21                                       Saint Laurent
# 22                                          PSI CRO AG
# 23                                                DOCS
# 24                                   Roche Diagnostics
# 25                                   Walter-Fach-Kraft
# 26                                       Roland Berger
# 27                  ipoque - a Rohde & Schwarz company
# 28                                         PENTASYS AG
# 29                                          Porsche AG
# 30                         Technical University Munich
# 31                                       SYSTEMIQ Ltd.
# 32                         Bayerische Staatsbibliothek
# 33                                         Bucherer AG
# 34                                              attune
# 35                                         MST HOLDING
# 36                                           HDI Group
# 37                                            iPAXX AG
# 38                                                LIME
# 39                              Aigner Immobilien GmbH
# 40                                               PIMCO
# 41                     Hit Handelsgruppe GmbH & Co. KG
# 42                                                DOCS
# 43                                               Bauer
# 44   RADAS Jobbörse & Personalvermittlung GmbH (-bu...
# 45                                Haas Zeitarbeit GmbH
# 46                                              Amazon
# 47                                   Accord Healthcare
# 48                   Institut Für Musikalische Bildung
# 49                                         Gleiss Lutz
# 50                                   Walter-Fach-Kraft
# 51                                       Roland Berger
# 52                  ipoque - a Rohde & Schwarz company
# 53                                         PENTASYS AG
# 54                                          Porsche AG
# 55                         Technical University Munich
# 56                                       SYSTEMIQ Ltd.
# 57                         Bayerische Staatsbibliothek
# 58                                         Bucherer AG
# 59                                              attune
# 60                                         MST HOLDING
# 61                                           HDI Group
# 62                                            iPAXX AG
# 63                                                LIME
# 64                              Aigner Immobilien GmbH
# 65                                               PIMCO
# 66                     Hit Handelsgruppe GmbH & Co. KG
# 67                                                DOCS
# 68                                               Bauer
# 69   RADAS Jobbörse & Personalvermittlung GmbH (-bu...
# 70                                Haas Zeitarbeit GmbH
# 71                                              Amazon
# 72                                   Accord Healthcare
# 73                   Institut Für Musikalische Bildung
# 74                                         Gleiss Lutz
# 75                                     Bundesdruckerei
# 76                                                KPIT
# 77                                   Euronet Worldwide
# 78                         Technical University Munich
# 79                                               PIMCO
# 80   metafinanz Informationssysteme GmbH (Allianz G...
# 81                                             Allianz
# 82                                           Abalon AB
# 83                                         VIU Eyewear
# 84                          Personalwerk Sourcing GmbH
# 85                                RS for business GmbH
# 86                                       Syneos Health
# 87                                               Infor
# 88                                       SYSTEMIQ Ltd.
# 89                                     Astellas Europe
# 90                                   Accord Healthcare
# 91                                       hilton hotels
# 92                           Helmholtz Zentrum München
# 93                           RequireTech Resources Ltd
# 94                                          Cybereason
# 95                                       Roland Berger
# 96                                       Saint Laurent
# 97                                          PSI CRO AG
# 98                                                DOCS
# 99                                   Roche Diagnostics
# 100                                  Walter-Fach-Kraft
# 101                                      Roland Berger
# 102                                        PENTASYS AG
# 103                                         Porsche AG
# 104                        Technical University Munich
# 105                                      SYSTEMIQ Ltd.
# 106                        Bayerische Staatsbibliothek
# 107                 ipoque - a Rohde & Schwarz company
# 108                                        Bucherer AG
# 109                                             attune
# 110                                        MST HOLDING
# 111                                          HDI Group
# 112                                           iPAXX AG
# 113                                               DOCS
# 114                                               LIME
# 115                             Aigner Immobilien GmbH
# 116                    Hit Handelsgruppe GmbH & Co. KG
# 117                                              Bauer
# 118  RADAS Jobbörse & Personalvermittlung GmbH (-bu...
# 119                               Haas Zeitarbeit GmbH
# 120                                             Amazon
# 121                                       State Street
# 122                                              PIMCO
# 123                                        Gleiss Lutz
# 124        Jongeren Organisatie Beroepsonderwijs (JOB)
#
#                                        Location
# 0                                    Munich, DE
# 1                      Munich, Bavaria, Germany
# 2                          Munich Area, Germany
# 3                                    Munich, DE
# 4                                    Munich, DE
# 5                                    Munich, DE
# 6                                    Munich, DE
# 7                                    Munich, DE
# 8                                    Munich, DE
# 9                  München, Bayern, Deutschland
# 10   Rosenheim (Landkreis), Bayern, Deutschland
# 11                     Munich, Bavaria, Germany
# 12                     Munich, Bavaria, Germany
# 13                     Munich, Bavaria, Germany
# 14                     Munich, Bavaria, Germany
# 15                     Munich, Bavaria, Germany
# 16                                   Munich, DE
# 17                                   Munich, DE
# 18                     Munich, Bavaria, Germany
# 19                     Munich, Bavaria, Germany
# 20                                   Munich, DE
# 21                                   Munich, DE
# 22                                   Munich, DE
# 23                     Munich, Bavaria, Germany
# 24                                   Munich, DE
# 25                                   Munich, DE
# 26                                   Munich, DE
# 27                                   Munich, DE
# 28                                   Munich, DE
# 29                                   Munich, DE
# 30                                   Munich, DE
# 31                     Munich, Bavaria, Germany
# 32                                   Munich, DE
# 33                                   Munich, DE
# 34                                   Munich, DE
# 35                                   Munich, DE
# 36                                   Munich, DE
# 37                                   Munich, DE
# 38                                   Munich, DE
# 39                                   Munich, DE
# 40                                   Munich, DE
# 41                                   Munich, DE
# 42                 München, Bayern, Deutschland
# 43                                   Munich, DE
# 44                                   Munich, DE
# 45                                   Munich, DE
# 46                                   Munich, DE
# 47                     Munich, Bavaria, Germany
# 48                                   Munich, DE
# 49                                   Munich, DE
# 50                                   Munich, DE
# 51                                   Munich, DE
# 52                                   Munich, DE
# 53                                   Munich, DE
# 54                                   Munich, DE
# 55                                   Munich, DE
# 56                     Munich, Bavaria, Germany
# 57                                   Munich, DE
# 58                                   Munich, DE
# 59                                   Munich, DE
# 60                                   Munich, DE
# 61                                   Munich, DE
# 62                                   Munich, DE
# 63                                   Munich, DE
# 64                                   Munich, DE
# 65                                   Munich, DE
# 66                                   Munich, DE
# 67                 München, Bayern, Deutschland
# 68                                   Munich, DE
# 69                                   Munich, DE
# 70                                   Munich, DE
# 71                                   Munich, DE
# 72                     Munich, Bavaria, Germany
# 73                                   Munich, DE
# 74                                   Munich, DE
# 75                                   Munich, DE
# 76                     Munich, Bavaria, Germany
# 77                         Munich Area, Germany
# 78                                   Munich, DE
# 79                                   Munich, DE
# 80                                   Munich, DE
# 81                                   Munich, DE
# 82                                   Munich, DE
# 83                                   Munich, DE
# 84                 München, Bayern, Deutschland
# 85   Rosenheim (Landkreis), Bayern, Deutschland
# 86                     Munich, Bavaria, Germany
# 87                     Munich, Bavaria, Germany
# 88                     Munich, Bavaria, Germany
# 89                     Munich, Bavaria, Germany
# 90                     Munich, Bavaria, Germany
# 91                                   Munich, DE
# 92                                   Munich, DE
# 93                     Munich, Bavaria, Germany
# 94                     Munich, Bavaria, Germany
# 95                                   Munich, DE
# 96                                   Munich, DE
# 97                                   Munich, DE
# 98                     Munich, Bavaria, Germany
# 99                                   Munich, DE
# 100                                  Munich, DE
# 101                                  Munich, DE
# 102                                  Munich, DE
# 103                                  Munich, DE
# 104                                  Munich, DE
# 105                    Munich, Bavaria, Germany
# 106                                  Munich, DE
# 107                                  Munich, DE
# 108                                  Munich, DE
# 109                                  Munich, DE
# 110                                  Munich, DE
# 111                                  Munich, DE
# 112                                  Munich, DE
# 113                München, Bayern, Deutschland
# 114                                  Munich, DE
# 115                                  Munich, DE
# 116                                  Munich, DE
# 117                                  Munich, DE
# 118                                  Munich, DE
# 119                                  Munich, DE
# 120                                  Munich, DE
# 121                                  Munich, DE
# 122                                  Munich, DE
# 123                                  Munich, DE
# 124                    Garching bei München, DE

# %% [markdown]
# ## Bonus Challenge
#
# Allow your function to also retrieve the "Seniority Level" of each job searched. Note that the Seniority Level info is not in the initial search results. You need to make a separate search request for each job card based on the `currentJobId` value which you can extract from the job card HTML.
#
# After you obtain the Seniority Level info, update the function and add it to a new column of the returned dataframe.

# %%
# your code here
