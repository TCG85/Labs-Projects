# %% [markdown]
# # Job Board Scraping Lab
#
# In this lab you will first see a minimal but fully functional code snippet to scrape the LinkedIn Job Search webpage. You will then work on top of the example code and complete several chanllenges.
#
# ### Some Resources
#
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %%
# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search(keywords):
    
    # Define the base url to be scraped.
    # All uppercase variable name signifies this is a constant and its value should never unchange
    BASE_URL = 'https://www.linkedin.com/jobs/search/?'
    
    # Assemble the full url with parameters
    scrape_url = ''.join([BASE_URL, 'keywords=', keywords])

    # Create a request to get the data from the server 
    page = requests.get(scrape_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    # Create an empty dataframe with the columns consisting of the information you want to capture
    columns = ['Title', 'Company', 'Location']
    data = pd.DataFrame(columns=columns)

    # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
    # Then in each job card, extract the job title, company, and location data.
    titles = []
    companies = []
    locations = []
    for card in soup.select("div.result-card__contents"):
        title = card.findChild("h3", recursive=False)
        company = card.findChild("h4", recursive=False)
        location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
        titles.append(title.string)
        companies.append(company.string)
        locations.append(location.string)
    
    # Inject job titles, companies, and locations into the empty dataframe
    zipped = zip(titles, companies, locations)
    for z in list(zipped):
        data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
    
    # Return dataframe
    return data

# %%
# Example to call the function

results = scrape_linkedin_job_search('data%20analysis')
results
# Out:
#                                 Title  \
# 0                      Data Scientist
# 1                        Data Analyst
# 2         Analyst, Data and Analytics
# 3                        Data Analyst
# 4                        Data Analyst
# 5                        Data Analyst
# 6               Data Analysis Manager
# 7              Data Analysis Engineer
# 8              Data Analyst, Insights
# 9   Data Analyst, Data Analytics & AI
# 10                       Data Analyst
# 11                       Data Analyst
# 12             Associate Data Analyst
# 13                       Data Analyst
# 14    Data Analyst- Field Reliability
# 15             Data Analyst, Insights
# 16                       Data Analyst
# 17                       Data Analyst
# 18                       Risk Analyst
# 19                     Data Scientist
# 20                       Data Analyst
# 21      Business Intelligence Analyst
# 22                     System Analyst
# 23                       Data Analyst
# 24                Junior Data Analyst
#
#                                             Company  \
# 0                                           Feather
# 1                                   RevGen Partners
# 2                             Digitas North America
# 3                                      Brightfield
# 4                              Arsenal Credit Union
# 5                                              Uber
# 6                                           Kinesso
# 7   Haystack LLC: A Mission Essential Group Company
# 8                                            Voyage
# 9                      Royal Caribbean Cruises Ltd.
# 10                                 Ian Martin Group
# 11                                    Planted, Inc.
# 12                                         ZoomInfo
# 13                                          Concero
# 14                                            Tesla
# 15                                           Voyage
# 16                        Chima Steakhouse, BBS USA
# 17                                      Brooksource
# 18                                             Boro
# 19                                Otis Elevator Co.
# 20                                     Apex Systems
# 21                                    Digicel Group
# 22                                           Sherpa
# 23                                             Hays
# 24                                     ettain group
#
#                                    Location
# 0                     New York City, NY, US
# 1                  Denver Metropolitan Area
# 2                Greater New York City Area
# 3                  Washington, D.C., DC, US
# 4                    Greater St. Louis Area
# 5                     San Francisco, CA, US
# 6                        New York, New York
# 7       Germantown, Maryland, United States
# 8                         Palo Alto, CA, US
# 9                             Miami, FL, US
# 10         Jackson, Michigan, United States
# 11                    New York City, NY, US
# 12                        Vancouver, WA, US
# 13                   Greater St. Louis Area
# 14                        Palo Alto, CA, US
# 15                        Palo Alto, CA, US
# 16  Fort Lauderdale, Florida, United States
# 17       Tampa/St. Petersburg, Florida Area
# 18         Chicago, Illinois, United States
# 19                       Farmington, CT, US
# 20    Owings Mills, Maryland, United States
# 21            Miami, Florida, United States
# 22           Charlotte, North Carolina Area
# 23     Weehawken, New Jersey, United States
# 24               Washington D.C. Metro Area

# %% [markdown]
# ## Challenge 1
#
# The first challenge for you is to update the `scrape_linkedin_job_search` function by adding a new parameter called `num_pages`. This will allow you to search more than 25 jobs with this function. Suggested steps:
#
# 1. Go to https://www.linkedin.com/jobs/search/?keywords=data%20analysis in your browser.
# 1. Scroll down the left panel and click the page 2 link. Look at how the URL changes and identify the page offset parameter.
# 1. Add `num_pages` as a new param to the `scrape_linkedin_job_search` function. Update the function code so that it uses a "for" loop to retrieve several pages of search results.
# 1. Test your new function by scraping 5 pages of the search results.
#
# Hint: Prepare for the case where there are less than 5 pages of search results. Your function should be robust enough to **not** trigger errors. Simply skip making additional searches and return all results if the search already reaches the end.

# %%
# your code here

pd.set_option('display.max_rows', 500) 
    
# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search_pages(keywords, num_pages):
    
        # Define the base url to be scraped.
        # All uppercase variable name signifies this is a constant and its value should never unchange
        BASE_URL = 'https://www.linkedin.com/jobs/search/?'
                   
        #page_counter = 0
        titles = []
        companies = []
        locations = []
        # Create an empty dataframe with the columns consisting of the information you want to capture
        columns = ['Title', 'Company', 'Location']
        data = pd.DataFrame(columns=columns)
            
        for page in range(num_pages):
     
            
            # Assemble the full url with parameters
            scrape_url = ''.join([BASE_URL, 'keywords=', keywords, '&start=', str(page*25)])
            
            # Create a request to get the data from the server 
            page = requests.get(scrape_url)
            soup = BeautifulSoup(page.text, 'html.parser')
            
            
            
            # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
            # Then in each job card, extract the job title, company, and location data.
            
            for card in soup.select("div.result-card__contents"):
                title = card.findChild("h3", recursive=False)
                company = card.findChild("h4", recursive=False)
                location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
                titles.append(title.string)
                companies.append(company.string)
                locations.append(location.string)
            
        # Inject job titles, companies, and locations into the empty dataframe
        zipped = zip(titles, companies, locations)
        for z in list(zipped):
            data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
                         
        # Return dataframe
        return data

results_2 = scrape_linkedin_job_search_pages('data%20analysis', 3)
results_2.head(75)
# Out:
#                                 Title  \
# 0                      Data Scientist
# 1                        Data Analyst
# 2         Analyst, Data and Analytics
# 3                        Data Analyst
# 4                        Data Analyst
# 5                        Data Analyst
# 6               Data Analysis Manager
# 7              Data Analysis Engineer
# 8              Data Analyst, Insights
# 9   Data Analyst, Data Analytics & AI
# 10                       Data Analyst
# 11                       Data Analyst
# 12             Associate Data Analyst
# 13                       Data Analyst
# 14    Data Analyst- Field Reliability
# 15             Data Analyst, Insights
# 16                       Data Analyst
# 17                       Data Analyst
# 18                       Risk Analyst
# 19                     Data Scientist
# 20                       Data Analyst
# 21      Business Intelligence Analyst
# 22                     System Analyst
# 23                       Data Analyst
# 24                Junior Data Analyst
# 25                     Data Scientist
# 26                       Data Analyst
# 27        Analyst, Data and Analytics
# 28                       Data Analyst
# 29                       Data Analyst
# 30                       Data Analyst
# 31              Data Analysis Manager
# 32             Data Analysis Engineer
# 33             Data Analyst, Insights
# 34  Data Analyst, Data Analytics & AI
# 35                       Data Analyst
# 36                       Data Analyst
# 37             Associate Data Analyst
# 38                       Data Analyst
# 39    Data Analyst- Field Reliability
# 40             Data Analyst, Insights
# 41                       Data Analyst
# 42                       Data Analyst
# 43                       Risk Analyst
# 44                     Data Scientist
# 45                       Data Analyst
# 46      Business Intelligence Analyst
# 47                     System Analyst
# 48                       Data Analyst
# 49                Junior Data Analyst
# 50                     Data Scientist
# 51                       Data Analyst
# 52        Analyst, Data and Analytics
# 53                       Data Analyst
# 54                       Data Analyst
# 55                       Data Analyst
# 56              Data Analysis Manager
# 57             Data Analysis Engineer
# 58             Data Analyst, Insights
# 59  Data Analyst, Data Analytics & AI
# 60                       Data Analyst
# 61                       Data Analyst
# 62             Associate Data Analyst
# 63                       Data Analyst
# 64    Data Analyst- Field Reliability
# 65             Data Analyst, Insights
# 66                       Data Analyst
# 67                       Data Analyst
# 68                     Data Scientist
# 69                       Data Analyst
# 70      Business Intelligence Analyst
# 71                       Data Analyst
# 72                     System Analyst
# 73                       Data Analyst
# 74                       Data Analyst
#
#                                             Company  \
# 0                                           Feather
# 1                                   RevGen Partners
# 2                             Digitas North America
# 3                                      Brightfield
# 4                              Arsenal Credit Union
# 5                                              Uber
# 6                                           Kinesso
# 7   Haystack LLC: A Mission Essential Group Company
# 8                                            Voyage
# 9                      Royal Caribbean Cruises Ltd.
# 10                                 Ian Martin Group
# 11                                    Planted, Inc.
# 12                                         ZoomInfo
# 13                                          Concero
# 14                                            Tesla
# 15                                           Voyage
# 16                        Chima Steakhouse, BBS USA
# 17                                      Brooksource
# 18                                             Boro
# 19                                Otis Elevator Co.
# 20                                     Apex Systems
# 21                                    Digicel Group
# 22                                           Sherpa
# 23                                             Hays
# 24                                     ettain group
# 25                                          Feather
# 26                                  RevGen Partners
# 27                            Digitas North America
# 28                                     Brightfield
# 29                             Arsenal Credit Union
# 30                                             Uber
# 31                                          Kinesso
# 32  Haystack LLC: A Mission Essential Group Company
# 33                                           Voyage
# 34                     Royal Caribbean Cruises Ltd.
# 35                                 Ian Martin Group
# 36                                    Planted, Inc.
# 37                                         ZoomInfo
# 38                                          Concero
# 39                                            Tesla
# 40                                           Voyage
# 41                        Chima Steakhouse, BBS USA
# 42                                      Brooksource
# 43                                             Boro
# 44                                Otis Elevator Co.
# 45                                     Apex Systems
# 46                                    Digicel Group
# 47                                           Sherpa
# 48                                             Hays
# 49                                     ettain group
# 50                                          Feather
# 51                                  RevGen Partners
# 52                            Digitas North America
# 53                                     Brightfield
# 54                             Arsenal Credit Union
# 55                                             Uber
# 56                                          Kinesso
# 57  Haystack LLC: A Mission Essential Group Company
# 58                                           Voyage
# 59                     Royal Caribbean Cruises Ltd.
# 60                                 Ian Martin Group
# 61                                    Planted, Inc.
# 62                                         ZoomInfo
# 63                                          Concero
# 64                                            Tesla
# 65                                           Voyage
# 66                        Chima Steakhouse, BBS USA
# 67                                      Brooksource
# 68                                Otis Elevator Co.
# 69                                     Apex Systems
# 70                                    Digicel Group
# 71                                       ioCurrents
# 72                                           Sherpa
# 73                                             Hays
# 74                                   Eliassen Group
#
#                                    Location
# 0                     New York City, NY, US
# 1                  Denver Metropolitan Area
# 2                Greater New York City Area
# 3                  Washington, D.C., DC, US
# 4                    Greater St. Louis Area
# 5                     San Francisco, CA, US
# 6                        New York, New York
# 7       Germantown, Maryland, United States
# 8                         Palo Alto, CA, US
# 9                             Miami, FL, US
# 10         Jackson, Michigan, United States
# 11                    New York City, NY, US
# 12                        Vancouver, WA, US
# 13                   Greater St. Louis Area
# 14                        Palo Alto, CA, US
# 15                        Palo Alto, CA, US
# 16  Fort Lauderdale, Florida, United States
# 17       Tampa/St. Petersburg, Florida Area
# 18         Chicago, Illinois, United States
# 19                       Farmington, CT, US
# 20    Owings Mills, Maryland, United States
# 21            Miami, Florida, United States
# 22           Charlotte, North Carolina Area
# 23     Weehawken, New Jersey, United States
# 24               Washington D.C. Metro Area
# 25                    New York City, NY, US
# 26                 Denver Metropolitan Area
# 27               Greater New York City Area
# 28                 Washington, D.C., DC, US
# 29                   Greater St. Louis Area
# 30                    San Francisco, CA, US
# 31                       New York, New York
# 32      Germantown, Maryland, United States
# 33                        Palo Alto, CA, US
# 34                            Miami, FL, US
# 35         Jackson, Michigan, United States
# 36                    New York City, NY, US
# 37                        Vancouver, WA, US
# 38                   Greater St. Louis Area
# 39                        Palo Alto, CA, US
# 40                        Palo Alto, CA, US
# 41  Fort Lauderdale, Florida, United States
# 42       Tampa/St. Petersburg, Florida Area
# 43         Chicago, Illinois, United States
# 44                       Farmington, CT, US
# 45    Owings Mills, Maryland, United States
# 46            Miami, Florida, United States
# 47           Charlotte, North Carolina Area
# 48     Weehawken, New Jersey, United States
# 49               Washington D.C. Metro Area
# 50                    New York City, NY, US
# 51                 Denver Metropolitan Area
# 52               Greater New York City Area
# 53                 Washington, D.C., DC, US
# 54                   Greater St. Louis Area
# 55                    San Francisco, CA, US
# 56                       New York, New York
# 57      Germantown, Maryland, United States
# 58                        Palo Alto, CA, US
# 59                            Miami, FL, US
# 60         Jackson, Michigan, United States
# 61                    New York City, NY, US
# 62                        Vancouver, WA, US
# 63                   Greater St. Louis Area
# 64                        Palo Alto, CA, US
# 65                        Palo Alto, CA, US
# 66  Fort Lauderdale, Florida, United States
# 67       Tampa/St. Petersburg, Florida Area
# 68                       Farmington, CT, US
# 69    Owings Mills, Maryland, United States
# 70            Miami, Florida, United States
# 71       Seattle, Washington, United States
# 72           Charlotte, North Carolina Area
# 73     Weehawken, New Jersey, United States
# 74       Rockville, Maryland, United States

# %% [markdown]
# ## Challenge 2
#
# Further improve your function so that it can search jobs in a specific country. Add the 3rd param to your function called `country`. The steps are identical to those in Challange 1.

# %%
# your code here

pd.set_option('display.max_rows', 500) 
    
# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search_pages(keywords, country, num_pages):
    
        # Define the base url to be scraped.
        # All uppercase variable name signifies this is a constant and its value should never unchange
        BASE_URL = 'https://www.linkedin.com/jobs/search/?'
                   
        #page_counter = 0
        titles = []
        companies = []
        locations = []
        # Create an empty dataframe with the columns consisting of the information you want to capture
        columns = ['Title', 'Company', 'Location']
        data = pd.DataFrame(columns=columns)
            
        for i in range(num_pages):
     
            
            # Assemble the full url with parameters
            scrape_url = ''.join([BASE_URL, 'keywords=', keywords, '&location=', country, '&start=', str(i*25)])
            
            # Create a request to get the data from the server 
            page = requests.get(scrape_url)
            soup = BeautifulSoup(page.text, 'html.parser')
            
            
            
            # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
            # Then in each job card, extract the job title, company, and location data.
            
            for card in soup.select("div.result-card__contents"):
                title = card.findChild("h3", recursive=False)
                company = card.findChild("h4", recursive=False)
                location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
                titles.append(title.string)
                companies.append(company.string)
                locations.append(location.string)
            
        # Inject job titles, companies, and locations into the empty dataframe
        zipped = zip(titles, companies, locations)
        for z in list(zipped):
            data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
                         
        # Return dataframe
        return data

results_3 = scrape_linkedin_job_search_pages('cluster%20lead', 'munich', 10)
results_3
# Out:
#                                              Title  \
# 0                          Cluster Lead, Market HR
# 1                        Transport Carrier Manager
# 2                           CRM Specialist (m/f/d)
# 3                            VP Talent Acquisition
# 4                          Product Manager (f/m/d)
# 5   Senior Software Engineer: JS Fullstack (m/f/d)
# 6                          Cluster Lead, Market HR
# 7                           CRM Specialist (m/f/d)
# 8                          Product Manager (f/m/d)
# 9                        Transport Carrier Manager
# 10                           VP Talent Acquisition
# 11  Senior Software Engineer: JS Fullstack (m/f/d)
# 12                         Cluster Lead, Market HR
# 13                          CRM Specialist (m/f/d)
# 14                         Product Manager (f/m/d)
# 15                       Transport Carrier Manager
# 16                           VP Talent Acquisition
# 17  Senior Software Engineer: JS Fullstack (m/f/d)
# 18                         Cluster Lead, Market HR
# 19                          CRM Specialist (m/f/d)
# 20                         Product Manager (f/m/d)
# 21                       Transport Carrier Manager
# 22                           VP Talent Acquisition
# 23  Senior Software Engineer: JS Fullstack (m/f/d)
# 24                         Cluster Lead, Market HR
# 25                           VP Talent Acquisition
# 26                          CRM Specialist (m/f/d)
# 27  Senior Software Engineer: JS Fullstack (m/f/d)
# 28                       Transport Carrier Manager
# 29                         Product Manager (f/m/d)
# 30                         Cluster Lead, Market HR
# 31                       Transport Carrier Manager
# 32                          CRM Specialist (m/f/d)
# 33                           VP Talent Acquisition
# 34                         Product Manager (f/m/d)
# 35  Senior Software Engineer: JS Fullstack (m/f/d)
# 36                         Cluster Lead, Market HR
# 37                       Transport Carrier Manager
# 38                          CRM Specialist (m/f/d)
# 39                           VP Talent Acquisition
# 40                         Product Manager (f/m/d)
# 41  Senior Software Engineer: JS Fullstack (m/f/d)
# 42                         Cluster Lead, Market HR
# 43                          CRM Specialist (m/f/d)
# 44                         Product Manager (f/m/d)
# 45                       Transport Carrier Manager
# 46                           VP Talent Acquisition
# 47  Senior Software Engineer: JS Fullstack (m/f/d)
# 48                         Cluster Lead, Market HR
# 49                       Transport Carrier Manager
# 50                          CRM Specialist (m/f/d)
# 51                           VP Talent Acquisition
# 52                         Product Manager (f/m/d)
# 53  Senior Software Engineer: JS Fullstack (m/f/d)
# 54                         Cluster Lead, Market HR
# 55                          CRM Specialist (m/f/d)
# 56                         Product Manager (f/m/d)
# 57                       Transport Carrier Manager
# 58                           VP Talent Acquisition
# 59  Senior Software Engineer: JS Fullstack (m/f/d)
#
#                                               Company    Location
# 0                                              Google  Munich, DE
# 1                                              Amazon  Munich, DE
# 2                                       Tiffany & Co.  Munich, DE
# 3   jobleads.com - Careers for Senior-Level Profes...  Munich, DE
# 4                                              Holidu  Munich, DE
# 5                                              Motius  Munich, DE
# 6                                              Google  Munich, DE
# 7                                       Tiffany & Co.  Munich, DE
# 8                                              Holidu  Munich, DE
# 9                                              Amazon  Munich, DE
# 10  jobleads.com - Careers for Senior-Level Profes...  Munich, DE
# 11                                             Motius  Munich, DE
# 12                                             Google  Munich, DE
# 13                                      Tiffany & Co.  Munich, DE
# 14                                             Holidu  Munich, DE
# 15                                             Amazon  Munich, DE
# 16  jobleads.com - Careers for Senior-Level Profes...  Munich, DE
# 17                                             Motius  Munich, DE
# 18                                             Google  Munich, DE
# 19                                      Tiffany & Co.  Munich, DE
# 20                                             Holidu  Munich, DE
# 21                                             Amazon  Munich, DE
# 22  jobleads.com - Careers for Senior-Level Profes...  Munich, DE
# 23                                             Motius  Munich, DE
# 24                                             Google  Munich, DE
# 25  jobleads.com - Careers for Senior-Level Profes...  Munich, DE
# 26                                      Tiffany & Co.  Munich, DE
# 27                                             Motius  Munich, DE
# 28                                             Amazon  Munich, DE
# 29                                             Holidu  Munich, DE
# 30                                             Google  Munich, DE
# 31                                             Amazon  Munich, DE
# 32                                      Tiffany & Co.  Munich, DE
# 33  jobleads.com - Careers for Senior-Level Profes...  Munich, DE
# 34                                             Holidu  Munich, DE
# 35                                             Motius  Munich, DE
# 36                                             Google  Munich, DE
# 37                                             Amazon  Munich, DE
# 38                                      Tiffany & Co.  Munich, DE
# 39  jobleads.com - Careers for Senior-Level Profes...  Munich, DE
# 40                                             Holidu  Munich, DE
# 41                                             Motius  Munich, DE
# 42                                             Google  Munich, DE
# 43                                      Tiffany & Co.  Munich, DE
# 44                                             Holidu  Munich, DE
# 45                                             Amazon  Munich, DE
# 46  jobleads.com - Careers for Senior-Level Profes...  Munich, DE
# 47                                             Motius  Munich, DE
# 48                                             Google  Munich, DE
# 49                                             Amazon  Munich, DE
# 50                                      Tiffany & Co.  Munich, DE
# 51  jobleads.com - Careers for Senior-Level Profes...  Munich, DE
# 52                                             Holidu  Munich, DE
# 53                                             Motius  Munich, DE
# 54                                             Google  Munich, DE
# 55                                      Tiffany & Co.  Munich, DE
# 56                                             Holidu  Munich, DE
# 57                                             Amazon  Munich, DE
# 58  jobleads.com - Careers for Senior-Level Profes...  Munich, DE
# 59                                             Motius  Munich, DE

# %% [markdown]
# ## Challenge 3
#
# Add the 4th param called `num_days` to your function to allow it to search jobs posted in the past X days. Note that in the LinkedIn job search the searched timespan is specified with the following param:
#
# ```
# f_TPR=r259200
# ```
#
# The number part in the param value is the number of seconds. 259,200 seconds equal to 3 days. You need to convert `num_days` to number of seconds and supply that info to LinkedIn job search.

# %%
# your code here

pd.set_option('display.max_rows', 500) 
    
# Import the required libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

"""
This function searches job posts from LinkedIn and converts the results into a dataframe.
"""
def scrape_linkedin_job_search_pages(keywords, country, num_pages, num_days):
    
        # Define the base url to be scraped.
        # All uppercase variable name signifies this is a constant and its value should never unchange
        BASE_URL = 'https://www.linkedin.com/jobs/search/?'
                   
        #page_counter = 0
        titles = []
        companies = []
        locations = []
        # Create an empty dataframe with the columns consisting of the information you want to capture
        columns = ['Title', 'Company', 'Location']
        data = pd.DataFrame(columns=columns)
            
        for i in range(num_pages):
     
            
            # Assemble the full url with parameters
            scrape_url = ''.join([BASE_URL, 'f_TPR=r', str((259200/3)*num_days),'keywords=', keywords, '&location=', country, '&start=', str(i*25)])
            
            # Create a request to get the data from the server 
            page = requests.get(scrape_url)
            soup = BeautifulSoup(page.text, 'html.parser')
            
            
            
            # Retrieve HTML code from the webpage. Parse the HTML into a list of "cards".
            # Then in each job card, extract the job title, company, and location data.
            
            for card in soup.select("div.result-card__contents"):
                title = card.findChild("h3", recursive=False)
                company = card.findChild("h4", recursive=False)
                location = card.findChild("span", attrs={"class": "job-result-card__location"}, recursive=True)
                titles.append(title.string)
                companies.append(company.string)
                locations.append(location.string)
            
        # Inject job titles, companies, and locations into the empty dataframe
        zipped = zip(titles, companies, locations)
        for z in list(zipped):
            data=data.append({'Title' : z[0] , 'Company' : z[1], 'Location': z[2]} , ignore_index=True)
                         
        # Return dataframe
        return data

results_4 = scrape_linkedin_job_search_pages('cluster%20lead', 'Munich', 5, 0)
results_4
# Out:
#                                                  Title  \
# 0                        Cooperation Assistant (m/f/d)
# 1                                       Women who code
# 2                           Personal Assistant (m/w/d)
# 3                                  Interviewer (m/w/d)
# 4                                         Data Analyst
# 5                       Resort Partnership Intern EMEA
# 6                       Junior Project Manager (w/m/d)
# 7                                       Office Manager
# 8                       Executive Assistant to the CEO
# 9                               Facilities Coordinator
# 10              Junior Market Research Analyst (m/w/d)
# 11                 Marketing Strategie Manager (m/w/d)
# 12   Assistant Manager (w/m/d) Business Development...
# 13                People & Events Professional (m/w/d)
# 14                                 Editorial Assistant
# 15   ASSOCIATE - M&A AND STRATEGY - HEALTHCARE - MU...
# 16          Visual Merchandiser (m/w/d) Emporio Armani
# 17                                 Consultant, Germany
# 18                                Operations Associate
# 19                         Executive Assistant (m/w/d)
# 20                 Associate at Allianz X GmbH (m/f/d)
# 21                          Front Desk Manager (m/w/d)
# 22                                  Specialist (m/w/d)
# 23                               Admissions Counsellor
# 24   Marketing Coordinator Sports & Entertainment (...
# 25       Data Scientist Analytics and Machine Learning
# 26                                       PHP Developer
# 27                      IT Helpdesk Specialist (m/f/d)
# 28                         Test Engineer - HIL (f,m,d)
# 29                           Procurement Manager Capex
# 30                                 SAP Program Manager
# 31                              Senior Sales Executive
# 32   Data Engineer – PL/SQL Development (m/f/d) in ...
# 33   Health Care Content Technical Sales Specialist...
# 34                   Hardware Certification Specialist
# 35            Switch Mode Power Supply Engineer (SMPS)
# 36               Software Test Engineer – Java (m/f/i)
# 37                     Junior Product Designer (m/w/d)
# 38   Assistant Manager (w/m/d) Business Development...
# 39                  Senior Global Product Manager (gn)
# 40                  Director Of Engineering Operations
# 41                                     Sales Assistant
# 42                              Java Developer (m/f/d)
# 43                Execution Trader Derivatives (m/w/d)
# 44     Regional Sales Manager - Semiconductor Industry
# 45   Computer Vision Engineer - Deep Learning, Mach...
# 46            KERING EYEWEAR - Trade Marketing Trainee
# 47                                EMEA Events Director
# 48                                       Sales Manager
# 49                        Enterprise Account Executive
# 50                                   Uhrmacher (m/w/d)
# 51      Softwaretester (m/w/d) für Testautomatisierung
# 52                 Key Account Manager (m/w/d) Avionik
# 53   Simulationsingenieur (m/w/d) Schwerpunkt Fahre...
# 54                          Personal Assistant (m/w/d)
# 55                      Executive Assistant to the CEO
# 56                                        Data Analyst
# 57   Scientist (f/m/d) Drug Product Characterizatio...
# 58           Junior Manager Assurance/Advisory (m/w/d)
# 59   Einsatzmöglichkeiten von Blockchain in der Aut...
# 60                     Associate (w/m/d) Restructuring
# 61                                EMEA Events Director
# 62                      Resort Partnership Intern EMEA
# 63                                      Office Manager
# 64    Corporate Account Executive, Nordrhein-Westfalen
# 65                              Credit Analyst (m/f/d)
# 66                             Director Of Engineering
# 67       Manager Internal Communications 30-40h/ Woche
# 68      HR Mitarbeiter (m/w/d) internationaler Konzern
# 69            Data Analyst (m/w/d) - Inhouse in Bayern
# 70                                 It projektleiter_in
# 71   ASSOCIATE - M&A AND STRATEGY - HEALTHCARE - MU...
# 72                           Marketing Content Manager
# 73                                 Editorial Assistant
# 74                  Property Manager (m/f/d) - München
# 75                                   Uhrmacher (m/w/d)
# 76      Softwaretester (m/w/d) für Testautomatisierung
# 77                 Key Account Manager (m/w/d) Avionik
# 78   Simulationsingenieur (m/w/d) Schwerpunkt Fahre...
# 79                          Personal Assistant (m/w/d)
# 80                      Executive Assistant to the CEO
# 81                                        Data Analyst
# 82   Scientist (f/m/d) Drug Product Characterizatio...
# 83           Junior Manager Assurance/Advisory (m/w/d)
# 84   Einsatzmöglichkeiten von Blockchain in der Aut...
# 85                     Associate (w/m/d) Restructuring
# 86                                EMEA Events Director
# 87                      Resort Partnership Intern EMEA
# 88                                      Office Manager
# 89    Corporate Account Executive, Nordrhein-Westfalen
# 90                              Credit Analyst (m/f/d)
# 91                             Director Of Engineering
# 92       Manager Internal Communications 30-40h/ Woche
# 93      HR Mitarbeiter (m/w/d) internationaler Konzern
# 94            Data Analyst (m/w/d) - Inhouse in Bayern
# 95                                 It projektleiter_in
# 96   ASSOCIATE - M&A AND STRATEGY - HEALTHCARE - MU...
# 97                           Marketing Content Manager
# 98                                 Editorial Assistant
# 99                  Property Manager (m/f/d) - München
# 100                                  Uhrmacher (m/w/d)
# 101     Softwaretester (m/w/d) für Testautomatisierung
# 102                Key Account Manager (m/w/d) Avionik
# 103  Simulationsingenieur (m/w/d) Schwerpunkt Fahre...
# 104                         Personal Assistant (m/w/d)
# 105                     Executive Assistant to the CEO
# 106                                       Data Analyst
# 107  Scientist (f/m/d) Drug Product Characterizatio...
# 108          Junior Manager Assurance/Advisory (m/w/d)
# 109  Einsatzmöglichkeiten von Blockchain in der Aut...
# 110                    Associate (w/m/d) Restructuring
# 111                               EMEA Events Director
# 112                     Resort Partnership Intern EMEA
# 113                                     Office Manager
# 114   Corporate Account Executive, Nordrhein-Westfalen
# 115                             Credit Analyst (m/f/d)
# 116                            Director Of Engineering
# 117      Manager Internal Communications 30-40h/ Woche
# 118     HR Mitarbeiter (m/w/d) internationaler Konzern
# 119           Data Analyst (m/w/d) - Inhouse in Bayern
# 120                                It projektleiter_in
# 121  ASSOCIATE - M&A AND STRATEGY - HEALTHCARE - MU...
# 122                          Marketing Content Manager
# 123                                Editorial Assistant
# 124                 Property Manager (m/f/d) - München
#
#                                                Company  \
# 0                                               Huawei
# 1                                             Futurice
# 2                                        Roland Berger
# 3                                        TNS Infratest
# 4                                               Amazon
# 5                                                GoPro
# 6                                            Mytheresa
# 7                                      PSB Recruitment
# 8                                 Limestone Capital AG
# 9                                            Mindspace
# 10                                International Campus
# 11                          Consors Finanz BNP Paribas
# 12                                    KPMG Deutschland
# 13                                         Campusjäger
# 14                              Hamilton Services GmbH
# 15                                       not disclosed
# 16                                      Giorgio Armani
# 17                                              Apptio
# 18                                          Cellebrite
# 19                                         Orizon GmbH
# 20                                             Allianz
# 21                                        Ritz Carlton
# 22                                      Munich Airport
# 23                                    Phorms Education
# 24                                        Getty Images
# 25   Fraunhofer Institute for Integrated Circuits I...
# 26                    thryve. (formerly Lennon Wright)
# 27                                             Altium®
# 28                                                KPIT
# 29                                          DSJ Global
# 30                      LTI - Larsen & Toubro Infotech
# 31                                        ITS European
# 32          IDS GmbH – Analysis and Reporting Services
# 33                                Proclinical Staffing
# 34                                               NATEK
# 35                                  Power Integrations
# 36                               astraia software gmbh
# 37                                            Personio
# 38                                    KPMG Deutschland
# 39                                           MorphoSys
# 40                           Hyperion Executive Search
# 41                                  Smith & Associates
# 42                        Bausparkasse Schwäbisch Hall
# 43                                      Baader Bank AG
# 44                   Pacific International Recruitment
# 45                                European Recruitment
# 46                                      Kering Eyewear
# 47                                            Fortinet
# 48                                    Mackenzie Stuart
# 49                                             Anaplan
# 50                                         Bucherer AG
# 51                                         PENTASYS AG
# 52                  ipoque - a Rohde & Schwarz company
# 53                                 IPG Automotive GmbH
# 54                                       Roland Berger
# 55                                Limestone Capital AG
# 56                                              Amazon
# 57                                     Coriolis Pharma
# 58                                           Noerr LLP
# 59                                         PENTASYS AG
# 60                                      Taylor Wessing
# 61                                            Fortinet
# 62                                               GoPro
# 63                                     PSB Recruitment
# 64                                          Okta, Inc.
# 65                                        State Street
# 66                    thryve. (formerly Lennon Wright)
# 67                                     HolidayCheck AG
# 68                                Haas Zeitarbeit GmbH
# 69                                     Jefferson Frank
# 70                        Bayerische Versorgungskammer
# 71                                       not disclosed
# 72                                        Contabo GmbH
# 73                              Hamilton Services GmbH
# 74                             BNP Paribas Real Estate
# 75                                         Bucherer AG
# 76                                         PENTASYS AG
# 77                  ipoque - a Rohde & Schwarz company
# 78                                 IPG Automotive GmbH
# 79                                       Roland Berger
# 80                                Limestone Capital AG
# 81                                              Amazon
# 82                                     Coriolis Pharma
# 83                                           Noerr LLP
# 84                                         PENTASYS AG
# 85                                      Taylor Wessing
# 86                                            Fortinet
# 87                                               GoPro
# 88                                     PSB Recruitment
# 89                                          Okta, Inc.
# 90                                        State Street
# 91                    thryve. (formerly Lennon Wright)
# 92                                     HolidayCheck AG
# 93                                Haas Zeitarbeit GmbH
# 94                                     Jefferson Frank
# 95                        Bayerische Versorgungskammer
# 96                                       not disclosed
# 97                                        Contabo GmbH
# 98                              Hamilton Services GmbH
# 99                             BNP Paribas Real Estate
# 100                                        Bucherer AG
# 101                                        PENTASYS AG
# 102                 ipoque - a Rohde & Schwarz company
# 103                                IPG Automotive GmbH
# 104                                      Roland Berger
# 105                               Limestone Capital AG
# 106                                             Amazon
# 107                                    Coriolis Pharma
# 108                                          Noerr LLP
# 109                                        PENTASYS AG
# 110                                     Taylor Wessing
# 111                                           Fortinet
# 112                                              GoPro
# 113                                    PSB Recruitment
# 114                                         Okta, Inc.
# 115                                       State Street
# 116                   thryve. (formerly Lennon Wright)
# 117                                    HolidayCheck AG
# 118                               Haas Zeitarbeit GmbH
# 119                                    Jefferson Frank
# 120                       Bayerische Versorgungskammer
# 121                                      not disclosed
# 122                                       Contabo GmbH
# 123                             Hamilton Services GmbH
# 124                            BNP Paribas Real Estate
#
#                          Location
# 0                      Munich, DE
# 1                      Munich, DE
# 2                      Munich, DE
# 3                      Munich, DE
# 4                      Munich, DE
# 5                      Munich, DE
# 6                    Aschheim, DE
# 7        Munich, Bavaria, Germany
# 8        Munich, Bavaria, Germany
# 9                      Munich, DE
# 10                     Munich, DE
# 11             München, 80336, DE
# 12                     Munich, DE
# 13               Unterföhring, DE
# 14           Munich Area, Germany
# 15                     Munich, DE
# 16                     Munich, DE
# 17                     Munich, DE
# 18                     Munich, DE
# 19                     Munich, DE
# 20                     Munich, DE
# 21                     Munich, DE
# 22                     Munich, DE
# 23                     Munich, DE
# 24                     Munich, DE
# 25                     Munich, DE
# 26           Munich Area, Germany
# 27   München, Bayern, Deutschland
# 28       Munich, Bavaria, Germany
# 29       Munich, Bavaria, Germany
# 30       Munich, Bavaria, Germany
# 31       Munich, Bavaria, Germany
# 32                     Munich, DE
# 33                     Munich, DE
# 34       Munich, Bavaria, Germany
# 35       Munich, Bavaria, Germany
# 36                     Munich, DE
# 37                     Munich, DE
# 38                     Munich, DE
# 39                 Gräfelfing, DE
# 40       Munich, Bavaria, Germany
# 41       Munich, Bavaria, Germany
# 42             München, 80331, DE
# 43           Unterschleißheim, DE
# 44   München, Bayern, Deutschland
# 45           Munich Area, Germany
# 46       Munich, Bavaria, Germany
# 47       Munich, Bavaria, Germany
# 48       Munich, Bavaria, Germany
# 49       Munich, Bavaria, Germany
# 50                     Munich, DE
# 51                     Munich, DE
# 52                     Munich, DE
# 53                     Munich, DE
# 54                     Munich, DE
# 55       Munich, Bavaria, Germany
# 56                     Munich, DE
# 57                     Munich, DE
# 58                     Munich, DE
# 59                     Munich, DE
# 60                     Munich, DE
# 61       Munich, Bavaria, Germany
# 62                     Munich, DE
# 63       Munich, Bavaria, Germany
# 64                     Munich, DE
# 65                     Munich, DE
# 66           Munich Area, Germany
# 67                     Munich, DE
# 68                     Munich, DE
# 69                     Munich, DE
# 70                     Munich, DE
# 71                     Munich, DE
# 72       Munich, Bavaria, Germany
# 73           Munich Area, Germany
# 74             München, 80539, DE
# 75                     Munich, DE
# 76                     Munich, DE
# 77                     Munich, DE
# 78                     Munich, DE
# 79                     Munich, DE
# 80       Munich, Bavaria, Germany
# 81                     Munich, DE
# 82                     Munich, DE
# 83                     Munich, DE
# 84                     Munich, DE
# 85                     Munich, DE
# 86       Munich, Bavaria, Germany
# 87                     Munich, DE
# 88       Munich, Bavaria, Germany
# 89                     Munich, DE
# 90                     Munich, DE
# 91           Munich Area, Germany
# 92                     Munich, DE
# 93                     Munich, DE
# 94                     Munich, DE
# 95                     Munich, DE
# 96                     Munich, DE
# 97       Munich, Bavaria, Germany
# 98           Munich Area, Germany
# 99             München, 80539, DE
# 100                    Munich, DE
# 101                    Munich, DE
# 102                    Munich, DE
# 103                    Munich, DE
# 104                    Munich, DE
# 105      Munich, Bavaria, Germany
# 106                    Munich, DE
# 107                    Munich, DE
# 108                    Munich, DE
# 109                    Munich, DE
# 110                    Munich, DE
# 111      Munich, Bavaria, Germany
# 112                    Munich, DE
# 113      Munich, Bavaria, Germany
# 114                    Munich, DE
# 115                    Munich, DE
# 116          Munich Area, Germany
# 117                    Munich, DE
# 118                    Munich, DE
# 119                    Munich, DE
# 120                    Munich, DE
# 121                    Munich, DE
# 122      Munich, Bavaria, Germany
# 123          Munich Area, Germany
# 124            München, 80539, DE

# %% [markdown]
# ## Bonus Challenge
#
# Allow your function to also retrieve the "Seniority Level" of each job searched. Note that the Seniority Level info is not in the initial search results. You need to make a separate search request for each job card based on the `currentJobId` value which you can extract from the job card HTML.
#
# After you obtain the Seniority Level info, update the function and add it to a new column of the returned dataframe.

# %%
# your code here
